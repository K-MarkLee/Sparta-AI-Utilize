# %%
from openai import OpenAI
import os

# %%
client = OpenAI(api_key=os.getenv("GPT_API_KEY"))

# %%
prompt = "Cats all around the house"

# %%
response = client.images.generate(
    model= "dall-e-3",
    prompt=prompt,
    size="1024x1024",
    quality="hd",
    n=1
)

image_url = response.data[0].url
print(image_url)
# Out:
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-lqj2qXFkWfDnwxJbahRE83Qz/user-TxXq32fpAPXmGNztyp9x4nQb/img-zK9ePykhItHPWcicllIyy9YM.png?st=2024-11-05T05%3A04%3A19Z&se=2024-11-05T07%3A04%3A19Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-11-04T19%3A43%3A29Z&ske=2024-11-05T19%3A43%3A29Z&sks=b&skv=2024-08-04&sig=Wie30nILUKtXwr9qsemy%2B%2B4coBS1XfpBXlLfeWrd1%2Bc%3D

# %%
from ultralytics import YOLO
import cv2
from matplotlib import pyplot as plt
# Out:
# Creating new Ultralytics Settings v0.0.6 file
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\vulca\AppData\Roaming\Ultralytics\settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# YOLOv8 모델 로드 (YOLOv8s)
model = YOLO('yolov8n.pt')  #
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8n.pt to 'yolov8n.pt'...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 14.2MB/s]

# %%
# 이미지 파일 경로
image_path = 'cats.png'

# 이미지를 모델에 입력하여 객체 탐지 수행
results = model(image_path)

# 탐지 결과 출력
result = results[0]
# Out:
# image 1/1 e:\SY work\Sparta\Sparta-code\Sparta-AI-Utilize\cats.png: 640x640 7 cats, 1 couch, 1 potted plant, 1 mouse, 5.6ms
# Speed: 3.0ms preprocess, 5.6ms inference, 105.8ms postprocess per image at shape (1, 3, 640, 640)

# %%
# 탐지된 객체들이 표시된 이미지를 가져옴
img_with_boxes = result.plot()  # result.plot()은 바운딩 박스가 포함된 이미지를 반환

# Matplotlib을 사용하여 이미지 출력
plt.imshow(cv2.cvtColor(img_with_boxes, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()
